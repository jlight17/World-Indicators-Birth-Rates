# %% [markdown]
# ## Module Assignment 3 - Josie Light
#
# ##### I decided to compare birth and fertility rates between the two countries of the Philippines and Indonesia

# %%
import numpy as np
np.set_printoptions(suppress=True)

import altair as alt

import pandas as pd
idx = pd.IndexSlice
pd.options.display.max_columns = 100

# %matplotlib inline
import matplotlib.pyplot as plt

import seaborn as sb

# %%
CHNandIND_BirthRates = pd.read_csv('China_India_BirthRates.csv')
CHNandIND_BirthRates.head(10)
# Out:
#   Country Name Country Code  \
# 0        China          CHN
# 1        China          CHN
# 2        China          CHN
# 3        China          CHN
# 4        China          CHN
# 5        India          IND
# 6        India          IND
# 7        India          IND
# 8        India          IND
# 9        India          IND
#
#                                          Series Name     Series Code  \
# 0               Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN
# 1  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 2            Life expectancy at birth, total (years)  SP.DYN.LE00.IN
# 3           Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 4    Mortality rate, under-5 (per 1,000 live births)     SH.DYN.MORT
# 5               Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN
# 6  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 7            Life expectancy at birth, total (years)  SP.DYN.LE00.IN
# ...

# %%
x = np.array(["China 2010 Birth Rate", "China 2020 Birth Rate", "India 2010 Birth Rate", "India 2020 Birth Rate"])
y = np.array([11.9, 8.52, 21.11, 17.437])
c = ('r', 'r', 'orange', 'orange')
plt.figure(figsize = (12,6))
plt.bar(x,y, color = c,)


plt.title("Birth Rate Comparison from 2010-2020")
plt.xlabel("Countries")
plt.ylabel('Birth Rate (%)')
# Out:
# Text(0, 0.5, 'Birth Rate (%)')

# %%
CHN_df = CHNandIND_Birth_df[CHNandIND_Birth_df['Country Name'] == 'China']
CHN_df
# Out:
#   Country Name Country Code  \
# 0        China          CHN
# 1        China          CHN
# 2        China          CHN
# 3        China          CHN
# 4        China          CHN
#
#                                          Series Name     Series Code  \
# 0               Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN
# 1  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 2            Life expectancy at birth, total (years)  SP.DYN.LE00.IN
# 3           Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 4    Mortality rate, under-5 (per 1,000 live births)     SH.DYN.MORT
#
#    2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# 0        11.9000        13.2700         14.570        13.0300        13.8300
# 1         7.3422         7.3596          7.377         7.4286         7.4802
# 2        74.4090        74.7080         75.013        75.3210        75.6290
# ...

# %%
IND_df = CHNandIND_Birth_df[CHNandIND_Birth_df['Country Name'] == 'India']
IND_df
# Out:
#   Country Name Country Code  \
# 5        India          IND
# 6        India          IND
# 7        India          IND
# 8        India          IND
# 9        India          IND
#
#                                          Series Name     Series Code  \
# 5               Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN
# 6  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 7            Life expectancy at birth, total (years)  SP.DYN.LE00.IN
# 8           Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 9    Mortality rate, under-5 (per 1,000 live births)     SH.DYN.MORT
#
#    2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# 5        21.1140        20.4950         19.923         19.416         18.984
# 6        34.6548        31.3534         28.052         25.077         22.102
# 7        66.6930        67.1300         67.545         67.931         68.286
# ...

# %%
CHN_pivotDF = pd.pivot_table(
               data = CHN_df,
               index = ['Country Name'],
               columns = 'Series Name', 
               values = ['2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', 
                        '2015 [YR2015]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]'],
)
CHN_pivotDF
# Out:
#                                                              2010 [YR2010]  \
# Series Name  Adolescent fertility rate (births per 1,000 women ages 15-19)
# Country Name
# China                                                    7.3422
#
#                                                    \
# Series Name  Birth rate, crude (per 1,000 people)
# Country Name
# China                                        11.9
#
#                                                        \
# Series Name  Fertility rate, total (births per woman)
# Country Name
# China                                           1.627
#
#                                                       \
# Series Name  Life expectancy at birth, total (years)
# Country Name
# China                                         74.409
#
#                                                               \
# Series Name  Mortality rate, under-5 (per 1,000 live births)
# Country Name
# China                                                   15.8
#
# ...

# %%
CHNandIND_Pop_df = pd.read_csv('China_India_Population.csv')
CHNandIND_Pop_df.head(2)
# Out:
#   Country Name Country Code        Series Name  Series Code  2010 [YR2010]  \
# 0        China          CHN  Population, total  SP.POP.TOTL   1.337705e+09
# 1        India          IND  Population, total  SP.POP.TOTL   1.234281e+09
#
#    2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  \
# 0   1.345035e+09   1.354190e+09   1.363240e+09   1.371860e+09   1.379860e+09
# 1   1.250288e+09   1.265780e+09   1.280842e+09   1.295601e+09   1.310152e+09
#
#    2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]
# 0   1.387790e+09   1.396215e+09   1.402760e+09   1.407745e+09   1.411100e+09
# 1   1.324517e+09   1.338677e+09   1.352642e+09   1.366418e+09   1.380004e+09

# %%
x = np.array(["China 2010 Pop", "China 2020 Pop", "India 2010 Pop", "India 2020 Pop"])
y = np.array([1.337705e+09, 1.411100e+09, 1.234281e+09, 1.380004e+09])
c = ('r', 'r', 'orange', 'orange')
plt.bar(x,y, color = c)

plt.title("Total population from 2010-2020 Comparison")
plt.xlabel("Countries")
plt.ylabel('Population (Billions)')
# Out:
# Text(0, 0.5, 'Population (Billions)')

# %%
birthCrudeRate = CHNandIND_Birth_df[phandInd_Births_df['Series Name'] == 'Birth rate, crude (per 1,000 people)']
birthCrudeRate
# Out:
#   Country Name Country Code                           Series Name  \
# 0        China          CHN  Birth rate, crude (per 1,000 people)
# 5        India          IND  Birth rate, crude (per 1,000 people)
#
#       Series Code  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 0  SP.DYN.CBRT.IN         11.900         13.270         14.570         13.030
# 5  SP.DYN.CBRT.IN         21.114         20.495         19.923         19.416
#
#    2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 0         13.830         11.990         13.570         12.640         10.860
# 5         18.984         18.625         18.332         18.083         17.857
#
#    2019 [YR2019]  2020 [YR2020]
# 0         10.410          8.520
# 5         17.644         17.437

# %%
adolescentFertRate = CHNandIND_Birth_df[phandInd_Births_df['Series Name'] == 
                                    'Adolescent fertility rate (births per 1,000 women ages 15-19)']
adolescentFertRate
# Out:
#   Country Name Country Code  \
# 1        China          CHN
# 6        India          IND
#
#                                          Series Name  Series Code  \
# 1  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 6  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
#
#    2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# 1         7.3422         7.3596          7.377         7.4286         7.4802
# 6        34.6548        31.3534         28.052        25.0770        22.1020
#
#    2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  \
# 1         7.5318         7.5834          7.635         7.6430         7.6510
# 6        19.1270        16.1520         13.177        12.0708        10.9646
#
#    2020 [YR2020]
# 1         7.6590
# 6         9.8584

# %%
lifeExpRate = CHNandIND_Birth_df[phandInd_Births_df['Series Name'] == 'Life expectancy at birth, total (years)']
lifeExpRate
# Out:
#   Country Name Country Code                              Series Name  \
# 2        China          CHN  Life expectancy at birth, total (years)
# 7        India          IND  Life expectancy at birth, total (years)
#
#       Series Code  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 2  SP.DYN.LE00.IN         74.409         74.708         75.013         75.321
# 7  SP.DYN.LE00.IN         66.693         67.130         67.545         67.931
#
#    2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 2         75.629         75.928         76.210         76.470         76.704
# 7         68.286         68.607         68.897         69.165         69.416
#
#    2019 [YR2019]  2020 [YR2020]
# 2         76.912         77.097
# 7         69.656         69.887

# %%
fertilityPerWRate = CHNandIND_Birth_df[phandInd_Births_df['Series Name']
                                             == 'Fertility rate, total (births per woman)']
fertilityPerWRate
# Out:
#   Country Name Country Code                               Series Name  \
# 3        China          CHN  Fertility rate, total (births per woman)
# 8        India          IND  Fertility rate, total (births per woman)
#
#       Series Code  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 3  SP.DYN.TFRT.IN          1.627          1.632          1.639          1.647
# 8  SP.DYN.TFRT.IN          2.581          2.506          2.439          2.381
#
#    2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 3          1.656          1.665          1.675          1.683          1.690
# 8          2.333          2.295          2.266          2.243          2.222
#
#    2019 [YR2019]  2020 [YR2020]
# 3          1.696          1.700
# 8          2.202          2.184

# %%
mortality_U5_Rate = CHNandIND_Birth_df[phandInd_Births_df['Series Name']
                                             == 'Mortality rate, under-5 (per 1,000 live births)']
mortality_U5_Rate
# Out:
#   Country Name Country Code                                      Series Name  \
# 4        China          CHN  Mortality rate, under-5 (per 1,000 live births)
# 9        India          IND  Mortality rate, under-5 (per 1,000 live births)
#
#    Series Code  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 4  SH.DYN.MORT           15.8           14.6           13.5           12.5
# 9  SH.DYN.MORT           58.2           55.0           52.0           49.0
#
#    2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 4           11.6           10.7            9.9            9.2            8.5
# 9           46.2           43.5           41.0           38.6           36.3
#
#    2019 [YR2019]  2020 [YR2020]
# 4            7.9            7.3
# 9           34.4           32.6
